# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm, datasets

# %%
from google.colab import files
uploadFile = files.upload()
# Out:
#      <input type="file" id="files-2a4387a8-000b-4888-aa4a-6d9a1bddfdb9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2a4387a8-000b-4888-aa4a-6d9a1bddfdb9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
temp = pd.read_csv("cars_raw.csv")
rawdf = pd.DataFrame(temp)
rawdf.isna().sum()
# Out:
# Year                       0
# Make                       0
# Model                      0
# Used/New                   0
# Price                      0
# ConsumerRating             0
# ConsumerReviews            0
# SellerType                 0
# SellerName                 0
# SellerRating               0
# SellerReviews              0
# StreetName                 0
# State                      0
# Zipcode                    0
# DealType                 222
# ComfortRating              0
# InteriorDesignRating       0
# PerformanceRating          0
# ValueForMoneyRating        0
# ExteriorStylingRating      0
# ReliabilityRating          0
# ExteriorColor              0
# InteriorColor              0
# Drivetrain                 0
# MinMPG                     0
# MaxMPG                     0
# FuelType                   0
# Transmission               0
# Engine                     0
# VIN                        0
# Stock#                     0
# Mileage                    0
# ...

# %%
rawdf.dropna(inplace=True)
rawdf.isna().sum()
# Out:
# Year                     0
# Make                     0
# Model                    0
# Used/New                 0
# Price                    0
# ConsumerRating           0
# ConsumerReviews          0
# SellerType               0
# SellerName               0
# SellerRating             0
# SellerReviews            0
# StreetName               0
# State                    0
# Zipcode                  0
# DealType                 0
# ComfortRating            0
# InteriorDesignRating     0
# PerformanceRating        0
# ValueForMoneyRating      0
# ExteriorStylingRating    0
# ReliabilityRating        0
# ExteriorColor            0
# InteriorColor            0
# Drivetrain               0
# MinMPG                   0
# MaxMPG                   0
# FuelType                 0
# Transmission             0
# Engine                   0
# VIN                      0
# Stock#                   0
# Mileage                  0
# dtype: int64

# %%
rawdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9157 entries, 0 to 9378
# Data columns (total 32 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Year                   9157 non-null   int64
#  1   Make                   9157 non-null   object
#  2   Model                  9157 non-null   object
#  3   Used/New               9157 non-null   object
#  4   Price                  9157 non-null   object
#  5   ConsumerRating         9157 non-null   float64
#  6   ConsumerReviews        9157 non-null   int64
#  7   SellerType             9157 non-null   object
#  8   SellerName             9157 non-null   object
#  9   SellerRating           9157 non-null   float64
#  10  SellerReviews          9157 non-null   int64
#  11  StreetName             9157 non-null   object
#  12  State                  9157 non-null   object
#  13  Zipcode                9157 non-null   object
# ...

# %%
# In rawdf.Price, there is noise which is not NaN
# If you try to convert Price data into int form without pre-processing, you will get error code
rawdf = rawdf[rawdf.Price != 'Not Priced']
rawdf['Price_int'] = rawdf.Price.str.replace('$','').str.replace(',','').astype('int')
rawdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9152 entries, 0 to 9378
# Data columns (total 33 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Year                   9152 non-null   int64
#  1   Make                   9152 non-null   object
#  2   Model                  9152 non-null   object
#  3   Used/New               9152 non-null   object
#  4   Price                  9152 non-null   object
#  5   ConsumerRating         9152 non-null   float64
#  6   ConsumerReviews        9152 non-null   int64
#  7   SellerType             9152 non-null   object
#  8   SellerName             9152 non-null   object
#  9   SellerRating           9152 non-null   float64
#  10  SellerReviews          9152 non-null   int64
#  11  StreetName             9152 non-null   object
#  12  State                  9152 non-null   object
#  13  Zipcode                9152 non-null   object
# ...

# %%
rawdf.columns
# Out:
# Index(['Year', 'Make', 'Model', 'Used/New', 'Price', 'ConsumerRating',
#        'ConsumerReviews', 'SellerType', 'SellerName', 'SellerRating',
#        'SellerReviews', 'StreetName', 'State', 'Zipcode', 'DealType',
#        'ComfortRating', 'InteriorDesignRating', 'PerformanceRating',
#        'ValueForMoneyRating', 'ExteriorStylingRating', 'ReliabilityRating',
#        'ExteriorColor', 'InteriorColor', 'Drivetrain', 'MinMPG', 'MaxMPG',
#        'FuelType', 'Transmission', 'Engine', 'VIN', 'Stock#', 'Mileage',
#        'Price_int'],
#       dtype='object')

# %%
rawdf.head()
# Out:
#    Year    Make         Model Used/New    Price  ConsumerRating  \
# 0  2019  Toyota     Sienna SE     Used  $39,998             4.6
# 1  2018    Ford  F-150 Lariat     Used  $49,985             4.8
# 2  2017     RAM  1500 Laramie     Used  $41,860             4.7
# 4  2020   Lexus        RX 350     Used  $49,000             4.8
# 5  2012  Toyota   4Runner SR5     Used  $23,541             4.7
#
#    ConsumerReviews SellerType  \
# 0               45     Dealer
# 1              817     Dealer
# 2              495     Dealer
# 4               76     Dealer
# 5               34     Dealer
#
#                                           SellerName  SellerRating  ...  \
# 0  CarMax Murrieta - Now offering Curbside Pickup...           3.3  ...
# 1                                    Giant Chevrolet           4.8  ...
# 2                             Gill Auto Group Madera           4.6  ...
# 4                                 Lexus of Henderson           4.8  ...
# ...

# %%
target_columns = [
    'Year','ConsumerRating','ConsumerReviews','SellerRating','SellerReviews','ComfortRating',
    'InteriorDesignRating','PerformanceRating','ValueForMoneyRating','ExteriorStylingRating',
    'ReliabilityRating','MinMPG','MaxMPG','Mileage','Price_int'
]

targetDf = rawdf[target_columns]
targetDf['CarAge'] = 2022 - targetDf['Year']
targetDf.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    Year  ConsumerRating  ConsumerReviews  SellerRating  SellerReviews  \
# 0  2019             4.6               45           3.3              3
# 1  2018             4.8              817           4.8            131
# 2  2017             4.7              495           4.6            249
# 4  2020             4.8               76           4.8           4755
# 5  2012             4.7               34           4.4           1071
#
#    ComfortRating  InteriorDesignRating  PerformanceRating  \
# 0            4.7                   4.6                4.6
# 1            4.9                   4.8                4.8
# ...

# %%
# you can change target columns and all the pre-processing code
# visualize anything you want based on the data
