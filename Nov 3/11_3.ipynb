# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
tempDic1 = {
    'a':1,
    'b':2,
    'c':3
}
tempSeries1 = pd.Series(data=tempDic1,index = ['a','b','c'])
tempSeries1
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
tempDic2 = {
    'a':2,
    'b':4,
    'c':6
}
tempSeries2 = pd.Series(data=tempDic2,index = ['a','b','c'])
tempSeries2
# Out:
# a    2
# b    4
# c    6
# dtype: int64

# %%
tempdf1 = pd.DataFrame(tempSeries1)
tempdf1
# Out:
#    0
# a  1
# b  2
# c  3

# %%
finaldf = pd.concat([tempdf1, tempSeries2], axis=1)
finaldf
# Out:
#    0  0
# a  1  2
# b  2  4
# c  3  6

# %%
finaldf.columns = ['temp1','temp2']
finaldf
# Out:
#    temp1  temp2
# a      1      2
# b      2      4
# c      3      6

# %%
finaldf.plot()

# %%
df = pd.DataFrame({
    'Name': ['John', 'Sammy', 'Joe'],
    'Age': [45, 38, 90],
    'Career': [20, 10, 30]
})

# %%
df.plot(x='Name',y='Age',kind='bar')

# %%
df
# Out:
#     Name  Age  Career
# 0   John   45      20
# 1  Sammy   38      10
# 2    Joe   90      30

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Career'], dtype='object')

# %%
df['CareerStartAge'] = df['Age']-df['Career']
df
# Out:
#     Name  Age  Career  CareerStartAge
# 0   John   45      20              25
# 1  Sammy   38      10              28
# 2    Joe   90      30              60

# %%
df.loc[1,'Name'] = None

# %%
df
# Out:
#    Name  Age  Career  CareerStartAge
# 0  John   45      20              25
# 1  None   38      10              28
# 2   Joe   90      30              60

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            2 non-null      object
#  1   Age             3 non-null      int64
#  2   Career          3 non-null      int64
#  3   CareerStartAge  3 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 224.0+ bytes

# %%
df.isna().sum()
# Out:
# Name              1
# Age               0
# Career            0
# CareerStartAge    0
# dtype: int64

# %%
df.dropna()
df
# Out:
#    Name  Age  Career  CareerStartAge
# 0  John   45      20              25
# 1  None   38      10              28
# 2   Joe   90      30              60

# %%
df.dropna(inplace=True)
df
# Out:
#    Name  Age  Career  CareerStartAge
# 0  John   45      20              25
# 2   Joe   90      30              60

# %%
df = pd.DataFrame({
    'Name': ['John', 'Sammy', 'Joe'],
    'Age': [45, 38, 90],
    'Career': [20, 10, 30]
})

# %%
df.loc[1,'Name'] = 'Cecom'
df.loc[1,'Age']=None
df
# Out:
#     Name   Age  Career
# 0   John  45.0      20
# 1  Cecom   NaN      10
# 2    Joe  90.0      30

# %%
df.fillna(method ='ffill')
# Out:
#     Name   Age  Career
# 0   John  45.0      20
# 1  Cecom  45.0      10
# 2    Joe  90.0      30

# %%
df.fillna(method ='bfill')
# Out:
#     Name   Age  Career
# 0   John  45.0      20
# 1  Cecom  90.0      10
# 2    Joe  90.0      30

# %%
df.fillna(df['Age'].me2an())
# Out:
#     Name   Age  Career
# 0   John  45.0      20
# 1  Cecom  67.5      10
# 2    Joe  90.0      30
